# %% [markdown]
# **Topics**
# - Reading an image file and converting it to a numpy array
# - Resizing an image
# - RGB to Grayscale conversion

# %%
# getting an image using web git
# !wget 'https://static.vecteezy.com/system/resources/thumbnails/035/353/470/small_2x/ai-generated-puppy-in-nature-on-autumn-forest-background-closeup-animal-portrait-ai-generated-photo.jpg'

# %% [markdown]
# **Libraries that can be used for image processing**
# 1. matplotlib.image
# 2. pillow
# 3. OpenCV(cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
print(img)
# Out:
# [[[59 59 35]
#   [59 59 35]
#   [59 59 35]
#   ...
#   [61 58 51]
#   [60 57 50]
#   [60 57 50]]
#
#  [[59 59 35]
#   [59 59 35]
#   [59 59 35]
#   ...
#   [61 58 51]
#   [60 57 50]
#   [60 57 50]]
#
#  [[59 59 35]
#   [59 59 35]
#   [59 59 35]
#   ...
#   [61 58 51]
#   [60 57 50]
#   [60 57 50]]
#
#  ...
#
#  [[12  5  0]
#   [10  3  0]
#   [ 9  4  0]
#   ...
#   [14 11  6]
#   [15 12  7]
#   [16 13  8]]
#
#  [[16  9  0]
#   [13  6  0]
#   [14  7  0]
#   ...
#   [14 11  6]
#   [15 12  7]
#   [16 13  8]]
#
#  [[21 14  4]
#   [17 10  0]
#   [18 11  3]
#   ...
#   [14 11  6]
#   [15 12  7]
#   [16 13  8]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Resizing the image using pillow library**

# %%
from PIL import Image

# %%
img = Image.open('dog.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB image to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (400, 600)

# %% [markdown]
# **Displaying the image**

# %%
cv2.imshow('img',grayscale_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
